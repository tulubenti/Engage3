# %%
# Movie IMDB rating 
# Import pandas and numpy libraries for data manipulation.
# The data manipulation capabilities of pandas are built on top of the numpy library. 
# Pandas is best at handling tabular data sets comprising different variable types (integer, float, double, etc.)
# Numpy is most suitable for performing basic numerical computations such as mean, median, range, etc. 
#Alongside, numpy also supports the creation of multi-dimensional arrays.

# %%
import pandas as pd
import numpy as np

# %%
# matplotlib.pyplot is a collection of command style functions that make plotting and data visualization. 
# Data visualization is very important to determine the relationship between variables.
# Seaborn is a Python data visualization library based on matplotlib.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
# load data to explore and prepare for preprocessing, for visualization, and further analysis.
# The data was saved in csv file and pd.read_csv function is used to open the data file.

# %%
df = pd.read_csv('C:\TBBacha\DataScience\movie_metadata.csv')

# %%
# Check the head of data frame
# The head() function displays the first five lines of the data and 
#this helps to understand what the content of the data table is.

# %%
df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %% [markdown]
# # Replace NaNs by average of the column

# %%
df = df.fillna(df.mean())

# %%
df.head()
# Out:
#    color      director_name  num_critic_for_reviews    duration  \
# 0  Color      James Cameron              723.000000  178.000000
# 1  Color     Gore Verbinski              302.000000  169.000000
# 2  Color         Sam Mendes              602.000000  148.000000
# 3  Color  Christopher Nolan              813.000000  164.000000
# 4    NaN        Doug Walker              140.194272  107.201074
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0              855.000000  Joel David Moore
# 1                    563.0             1000.000000     Orlando Bloom
# 2                      0.0              161.000000      Rory Kinnear
# 3                  22000.0            23000.000000    Christian Bale
# 4                    131.0              645.009761        Rob Walker
#
#    actor_1_facebook_likes         gross                           genres  ...  \
# 0                  1000.0  7.605058e+08  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %% [markdown]
# # Get the basic information of the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
# color                        5024 non-null object
# director_name                4939 non-null object
# num_critic_for_reviews       5043 non-null float64
# duration                     5043 non-null float64
# director_facebook_likes      5043 non-null float64
# actor_3_facebook_likes       5043 non-null float64
# actor_2_name                 5030 non-null object
# actor_1_facebook_likes       5043 non-null float64
# gross                        5043 non-null float64
# genres                       5043 non-null object
# actor_1_name                 5036 non-null object
# movie_title                  5043 non-null object
# num_voted_users              5043 non-null int64
# cast_total_facebook_likes    5043 non-null int64
# actor_3_name                 5020 non-null object
# facenumber_in_poster         5043 non-null float64
# ...

# %% [markdown]
# # Get statistical information of the numerical data

# %%
df.describe()
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             5043.000000  5043.000000              5043.000000
# mean               140.194272   107.201074               686.509212
# std                120.997229    25.159932              2784.162531
# min                  1.000000     7.000000                 0.000000
# 25%                 50.000000    93.000000                 7.000000
# 50%                111.000000   103.000000                52.000000
# 75%                194.000000   118.000000               218.000000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             5043.000000             5043.000000  5.043000e+03
# mean               645.009761             6560.047061  4.846841e+07
# std               1661.239692            15010.328553  6.216318e+07
# min                  0.000000                0.000000  1.620000e+02
# ...

# %% [markdown]
# # Data exploratory

# %%
sns.distplot(df['imdb_score'])

# %%
df.corr()
# Out:
#                            num_critic_for_reviews  duration  \
# num_critic_for_reviews                   1.000000  0.255242
# duration                                 0.255242  1.000000
# director_facebook_likes                  0.178907  0.153708
# actor_3_facebook_likes                   0.270935  0.123012
# actor_1_facebook_likes                   0.189727  0.088377
# gross                                    0.441966  0.204975
# num_voted_users                          0.623805  0.314597
# cast_total_facebook_likes                0.262899  0.123033
# facenumber_in_poster                    -0.033633  0.013361
# num_user_for_reviews                     0.608509  0.326152
# budget                                   0.115756  0.064412
# title_year                               0.272200 -0.119520
# actor_2_facebook_likes                   0.281758  0.131229
# imdb_score                               0.302808  0.260886
# aspect_ratio                            -0.047702 -0.085871
# ...

# %% [raw]
# # Check correlations

# %%
sns.heatmap(df.corr(), annot = True)
sns.set(rc={'figure.figsize':(30,25)})
sns.set(font_scale=3)

# %% [markdown]
# # Training and testing data

# %%
# The data we use is usually split into training data and test data. 
# The training set contains a known output and the model learns on this data in order to be generalized to other data later on. 
# We have the test dataset (or subset) in order to test our model’s prediction on this subset.

# %%
df.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
# X represents the independent variables that may affect the movie rating.

# %%
X = df[['num_critic_for_reviews', 'duration',
       'director_facebook_likes', 'actor_3_facebook_likes',
       'actor_1_facebook_likes', 'gross', 'num_voted_users', 'cast_total_facebook_likes',
       'facenumber_in_poster', 'num_user_for_reviews', 'budget', 'title_year', 'actor_2_facebook_likes',
       'aspect_ratio', 'movie_facebook_likes']]

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 15 columns):
# num_critic_for_reviews       5043 non-null float64
# duration                     5043 non-null float64
# director_facebook_likes      5043 non-null float64
# actor_3_facebook_likes       5043 non-null float64
# actor_1_facebook_likes       5043 non-null float64
# gross                        5043 non-null float64
# num_voted_users              5043 non-null int64
# cast_total_facebook_likes    5043 non-null int64
# facenumber_in_poster         5043 non-null float64
# num_user_for_reviews         5043 non-null float64
# budget                       5043 non-null float64
# title_year                   5043 non-null float64
# actor_2_facebook_likes       5043 non-null float64
# aspect_ratio                 5043 non-null float64
# movie_facebook_likes         5043 non-null int64
# dtypes: float64(12), int64(3)
# memory usage: 591.1 KB

# %%
# y represents the movie rating dependent variable.

# %%
y = df['imdb_score']

# %% [markdown]
# # Split the data into training data and test data

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=101)

# %% [markdown]
# # linear regression

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(lm.intercept_)
# Out:
# 52.93507166285468

# %%
# Print out the coefficients of the model

# %%
lm.coef_
# Out:
# array([ 2.28536437e-03,  6.09639057e-03,  7.95875753e-06,  8.05553916e-05,
#         6.80306735e-05, -2.12856282e-09,  3.38124479e-06, -6.68709119e-05,
#        -2.69810248e-02, -4.93912958e-04,  1.32453696e-11, -2.37904982e-02,
#         6.69780645e-05,  9.78037365e-02, -8.12943581e-07])

# %%
X_train.columns
# Out:
# Index(['num_critic_for_reviews', 'duration', 'director_facebook_likes',
#        'actor_3_facebook_likes', 'actor_1_facebook_likes', 'gross',
#        'num_voted_users', 'cast_total_facebook_likes', 'facenumber_in_poster',
#        'num_user_for_reviews', 'budget', 'title_year',
#        'actor_2_facebook_likes', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
cdf = pd.DataFrame(lm.coef_, X.columns, columns =['Coeff'])

# %%
cdf
# Out:
#                                   Coeff
# num_critic_for_reviews     2.285364e-03
# duration                   6.096391e-03
# director_facebook_likes    7.958758e-06
# actor_3_facebook_likes     8.055539e-05
# actor_1_facebook_likes     6.803067e-05
# gross                     -2.128563e-09
# num_voted_users            3.381245e-06
# cast_total_facebook_likes -6.687091e-05
# facenumber_in_poster      -2.698102e-02
# num_user_for_reviews      -4.939130e-04
# budget                     1.324537e-11
# title_year                -2.379050e-02
# actor_2_facebook_likes     6.697806e-05
# aspect_ratio               9.780374e-02
# movie_facebook_likes      -8.129436e-07

# %%
predictors = X_train.columns

# %%
lm_coef = pd.Series(lm.coef_,predictors).sort_values()

# %%
lm_coef.plot(kind='bar')
plt.ylabel('Coefficients')
# Out:
# Text(0, 0.5, 'Coefficients')

# %% [markdown]
# # Predictions: predicting test data

# %%
predictions = lm.predict(X_test)

# %%
# Scatter plot of the real test values and the predicted values

# %%
plt.scatter(y_test, predictions)
plt.xlabel('Y Test (True values)')
plt.ylabel('Predicted values')
# Out:
# Text(0, 0.5, 'Predicted values')

# %% [markdown]
# # Residuals

# %%
sns.distplot(y_test - predictions)

# %% [markdown]
# # Evaluating model

# %%
from sklearn import metrics

# %%
mse_lm = metrics.mean_squared_error(y_test,predictions)

# %%
mse_lm
# Out:
# 0.946823427173053

# %% [markdown]
# # Ridge regression
# Ridge regression reduces model complexity and prevent over-fitting which may result from simple linear regression.
# This model shrinks the coefficients and it helps to reduce the model complexity and multi-collinearity.
# In ridge regression, the cost function is altered by adding a penalty equivalent to square of the magnitude of the coefficients.

# %%
from sklearn.linear_model import Ridge

# %%
# Training model

# %%
ridgeReg = Ridge(alpha=0.0001, normalize=True)
ridgeReg1 = Ridge(alpha = 0.01, normalize = True)
ridgeReg2 = Ridge(alpha = 1, normalize = True)

# %%
ridgeReg.fit(X_train,y_train)
ridgeReg1.fit(X_train,y_train)
ridgeReg2.fit(X_train,y_train)
# Out:
# Ridge(alpha=1, copy_X=True, fit_intercept=True, max_iter=None, normalize=True,
#       random_state=None, solver='auto', tol=0.001)

# %%
pred = ridgeReg.predict(X_test)
pred1 = ridgeReg1.predict(X_test)
pred2 = ridgeReg2.predict(X_test)

# %%
# Calculating mse

# %%
from sklearn import metrics

# %%
mse_ridge = metrics.mean_squared_error(y_test,pred)
mse_ridge1 = metrics.mean_squared_error(y_test,pred1)
mse_ridge2 = metrics.mean_squared_error(y_test,pred2)

# %%
mse_rig =[mse_ridge, mse_ridge1, mse_ridge2]
alpha =['alpha = 0.0001', 'alpha = 0.01', 'alpha = 1']
mse_rig
# Out:
# [0.9471263122163045, 0.9554911885926279, 1.043774751581061]

# %%
MSE_RIG = pd.Series(mse_rig,alpha).sort_values()

# %%
MSE_RIG.plot(kind ='bar')
plt.ylim(0.9, 1.05)
# Out:
# (0.9, 1.05)

# %%
ridgeReg.coef_
# Out:
# array([ 2.28531993e-03,  6.09323531e-03,  7.94667565e-06,  7.37404180e-05,
#         6.35567320e-05, -2.14490887e-09,  3.38256557e-06, -6.24075348e-05,
#        -2.70511247e-02, -4.93594031e-04,  1.33501489e-11, -2.37994805e-02,
#         6.24790102e-05,  9.77994260e-02, -8.24450811e-07])

# %%
cdf_ridge = pd.DataFrame(ridgeReg.coef_, X.columns, columns =['Ridge Coeff'])

# %%
cdf_ridge
# Out:
#                             Ridge Coeff
# num_critic_for_reviews     2.285320e-03
# duration                   6.093235e-03
# director_facebook_likes    7.946676e-06
# actor_3_facebook_likes     7.374042e-05
# actor_1_facebook_likes     6.355673e-05
# gross                     -2.144909e-09
# num_voted_users            3.382566e-06
# cast_total_facebook_likes -6.240753e-05
# facenumber_in_poster      -2.705112e-02
# num_user_for_reviews      -4.935940e-04
# budget                     1.335015e-11
# title_year                -2.379948e-02
# actor_2_facebook_likes     6.247901e-05
# aspect_ratio               9.779943e-02
# movie_facebook_likes      -8.244508e-07

# %%
# Checking the magnitude of coefficients

# %%
predictors = X_train.columns

# %%
ridge_coef = pd.Series(ridgeReg.coef_,predictors).sort_values()
ridge_coef1 = pd.Series(ridgeReg1.coef_,predictors).sort_values()
ridge_coef2 = pd.Series(ridgeReg2.coef_,predictors).sort_values()

# %%
ridge_coef.plot(kind='bar', title='Alpha = 0.01')
ridge_coef1.plot(kind='bar', title='Alpha = 0.01')
ridge_coef2.plot(kind='bar', title='Alpha = 0.01')

# %%
plt.scatter(y_test, pred)
plt.xlabel('Y Test (True values)')
plt.ylabel('Predicted values')
# Out:
# Text(0, 0.5, 'Predicted values')

# %% [markdown]
# # Lasso (Least Absolute Shrinkage and Selection Operator) regression regression
# Lasso regression not only helps in reducing over-fitting but it can help us in feature selection.

# %%
from sklearn.linear_model import Lasso

# %%
lassoReg = Lasso(alpha= 0.0001, normalize=True)
lassoReg1 = Lasso(alpha= 0.01, normalize=True)
lassoReg2 = Lasso(alpha= 1, normalize=True)

# %%
lassoReg.fit(X_train,y_train)
lassoReg1.fit(X_train,y_train)
lassoReg2.fit(X_train,y_train)
# Out:
# Lasso(alpha=1, copy_X=True, fit_intercept=True, max_iter=1000, normalize=True,
#       positive=False, precompute=False, random_state=None, selection='cyclic',
#       tol=0.0001, warm_start=False)

# %%
predLasso = lassoReg.predict(X_test)
predLasso1 = lassoReg1.predict(X_test)
predLasso2 = lassoReg2.predict(X_test)

# %%
mse_lasso = metrics.mean_squared_error(y_test,predLasso)
mse_lasso1 = metrics.mean_squared_error(y_test,predLasso1)
mse_lasso2 = metrics.mean_squared_error(y_test,predLasso2)

# %%
MSE_LASSO = [mse_lasso,mse_lasso1, mse_lasso2]
alphaLasso =['alpha = 0.0001', 'alpha = 0.01', 'alpha = 1']
MSE_LASSO
# Out:
# [0.9575557563557583, 1.2926097312545808, 1.2926097312545808]

# %%
MSE_LASS = pd.Series(MSE_LASSO,alpha).sort_values()

# %%
MSE_LASS.plot(kind ='bar')
# plt.ylim(0.9, 1.05)

# %%
lassoReg.coef_
# Out:
# array([ 2.07633532e-03,  5.81901105e-03,  7.01269169e-06, -1.90853795e-05,
#         7.34433572e-07, -2.19434841e-09,  3.17899464e-06, -0.00000000e+00,
#        -2.54807991e-02, -3.99097498e-04,  0.00000000e+00, -2.33433446e-02,
#        -0.00000000e+00,  9.16480399e-02, -0.00000000e+00])

# %%
cdf_lasso = pd.DataFrame(lassoReg.coef_, X.columns, columns =['Lasso Coeff'])

# %%
cdf_lasso
# Out:
#                             Lasso Coeff
# num_critic_for_reviews     2.076335e-03
# duration                   5.819011e-03
# director_facebook_likes    7.012692e-06
# actor_3_facebook_likes    -1.908538e-05
# actor_1_facebook_likes     7.344336e-07
# gross                     -2.194348e-09
# num_voted_users            3.178995e-06
# cast_total_facebook_likes -0.000000e+00
# facenumber_in_poster      -2.548080e-02
# num_user_for_reviews      -3.990975e-04
# budget                     0.000000e+00
# title_year                -2.334334e-02
# actor_2_facebook_likes    -0.000000e+00
# aspect_ratio               9.164804e-02
# movie_facebook_likes      -0.000000e+00

# %%
Lasso_coef = pd.Series(lassoReg.coef_,predictors).sort_values()
Lasso_coef1 = pd.Series(lassoReg1.coef_,predictors).sort_values()
Lasso_coef2 = pd.Series(lassoReg2.coef_,predictors).sort_values()

# %%
Lasso_coef.plot(kind='bar', title='Alpha = 0.0005')
Lasso_coef.plot(kind='bar', title='Alpha = 0.005')
Lasso_coef.plot(kind='bar', title='Alpha = 0.5')

# %%
plt.scatter(y_test, predLasso)
plt.xlabel('Y Test (True values)')
plt.ylabel('Predicted values')
# Out:
# Text(0, 0.5, 'Predicted values')

# %%
# Comparison of mean square errors of the three models

# %%
MDLS=['Linear Regression', 'Ridge Regression', 'Lasso Regression']

# %%
mses = [mse_lm, mse_ridge, mse_lasso]

# %%
mses_comparison=pd.Series(mses,MDLS)

# %%
mses_comparison.plot(kind='bar',title='Mean Squared Errors')
plt.ylabel('mean squared error')
plt.ylim(.94, 0.96)
# Out:
# (0.94, 0.96)

# %%
# Linear regression has the lowest mean squared error which inplies that the predictions is closer to the actual values. 
#The best model to predict the movie rating is linear regression and is give as:

# %%
imdb_score = num_critic_for_reviews*2.285364e-03 + duration*6.096391e-03 + director_facebook_likes*7.958758e-06 + 
actor_3_facebook_likes*8.055539e-05 + actor_1_facebook_likes*6.803067e-05 + gross*-2.128563e-09 + num_voted_users*3.381245e-06 + 
cast_total_facebook_likes*-6.687091e-05 + facenumber_in_poster*-2.698102e-02 + num_user_for_reviews*-4.939130e-04 + 
budget*1.324537e-11 + title_year	-2.379050e-02 + actor_2_facebook_likes*6.697806e-05 + aspect_ratio*9.780374e-02 + 
movie_facebook_likes*-8.129436e-07 + 52.935071662818196
# Out:
#   File "<ipython-input-176-458b1edc84c2>", line 1
#     imdb_score = num_critic_for_reviews*2.285364e-03 + duration*6.096391e-03 + director_facebook_likes*7.958758e-06 +
#                                                                                                                       ^
# SyntaxError: invalid syntax
